# %%
from mud import Player, World, MUDIndexerSDK
# Out:
# /Users/nico/.virtualenvs/woww/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
abi_dir = "./cafecosmos-contracts/abi"
rpc = "https://rpc.garnetchain.com"
world_address = "0x0209FE2b6C1a2B8cE12D8d9D6cf2D78a3Ff324FE"

indexer_url = "https://indexer.mud.garnetchain.com/q"
mud_config_path = "./cafecosmos-contracts/mud.config.ts"

world = World(rpc, 
              world_address, 
              abi_dir, 
              indexer_url=indexer_url, 
              mud_config_path=mud_config_path)

# %%
world.calculateArea(1,1)
# Out:
# 1

# %%
world.indexer.LandCell.get(landId=1)
# Out:
# payload [{'address': '0x0209FE2b6C1a2B8cE12D8d9D6cf2D78a3Ff324FE', 'query': 'SELECT landId, x, y, zItemCount FROM LandCell WHERE landId=1 LIMIT 1000;'}]
# [{'landid': '1', 'x': '0', 'y': '7', 'zitemcount': '1'},
#  {'landid': '1', 'x': '0', 'y': '9', 'zitemcount': '1'},
#  {'landid': '1', 'x': '0', 'y': '2', 'zitemcount': '1'},
#  {'landid': '1', 'x': '0', 'y': '0', 'zitemcount': '1'},
#  {'landid': '1', 'x': '0', 'y': '1', 'zitemcount': '1'},
#  {'landid': '1', 'x': '0', 'y': '4', 'zitemcount': '1'},
#  {'landid': '1', 'x': '0', 'y': '3', 'zitemcount': '1'},
#  {'landid': '1', 'x': '0', 'y': '5', 'zitemcount': '0'},
#  {'landid': '1', 'x': '1', 'y': '4', 'zitemcount': '1'},
#  {'landid': '1', 'x': '1', 'y': '6', 'zitemcount': '1'},
#  {'landid': '1', 'x': '1', 'y': '5', 'zitemcount': '1'},
#  {'landid': '1', 'x': '1', 'y': '1', 'zitemcount': '2'},
#  {'landid': '1', 'x': '1', 'y': '0', 'zitemcount': '1'},
#  {'landid': '1', 'x': '1', 'y': '3', 'zitemcount': '2'},
# ...

# %%
player = Player(env_key_name="PLAYER1")
player.add_world(world, "cafecosmos")

# %%
landId = 4

# %%
player.cafecosmos.indexer.ActiveStoves.get()
# Out:
# payload [{'address': '0x0209FE2b6C1a2B8cE12D8d9D6cf2D78a3Ff324FE', 'query': 'SELECT itemId, totalActiveStoves FROM ActiveStoves LIMIT 1000;'}]
# [{'itemid': '79', 'totalactivestoves': '9'}]

# %%
# while True:
#     player.cafecosmos.placeItem(landId, 1,1, unlock)
#     time.sleep(player.cafecosmos.indexer.Transfromations.get())
#     player.cafecosmos.placeItem(landId, 1,1, seed)
#     player.cafecosmos.placeItem(landId, 1,1, water)
#     player.cafecosmos.placeItem(landId, 1,1, water)
#     player.cafecosmos.placeItem(landId, 1,1, water)
#     player.cafecosmos.placeItem(landId, 1,1, unlock)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 while True:
# ----> 2     player.cafecosmos.placeItem(landId, 1,1, unlock)
#       3     time.sleep(player.cafecosmos.indexer.Transfromations.get())
#       4     player.cafecosmos.placeItem(landId, 1,1, seed)
#
# NameError: name 'unlock' is not defined

# %%
player.cafecosmos.indexer.LandItem.get(landId=landId)
# Out:
# [{'landid': '4',
#   'x': '0',
#   'y': '2',
#   'z': '0',
#   'itemid': '0',
#   'placementtime': '1734778252',
#   'dynamicunlocktimes': '0',
#   'dynamictimeouttimes': '0',
#   'isrotated': False},
#  {'landid': '4',
#   'x': '0',
#   'y': '4',
#   'z': '0',
#   'itemid': '0',
#   'placementtime': '1734778252',
#   'dynamicunlocktimes': '0',
#   'dynamictimeouttimes': '0',
#   'isrotated': False},
#  {'landid': '4',
#   'x': '0',
#   'y': '1',
#   'z': '0',
#   'itemid': '0',
#   'placementtime': '1734778252',
#   'dynamicunlocktimes': '0',
#   'dynamictimeouttimes': '0',
#   'isrotated': False},
#  {'landid': '4',
#   'x': '0',
#   'y': '0',
#   'z': '0',
#   'itemid': '0',
#   'placementtime': '1734778252',
#   'dynamicunlocktimes': '0',
#   'dynamictimeouttimes': '0',
#   'isrotated': False},
#  {'landid': '4',
#   'x': '0',
#   'y': '3',
#   'z': '0',
#   'itemid': '57',
#   'placementtime': '1734780796',
#   'dynamicunlocktimes': '0',
#   'dynamictimeouttimes': '0',
# ...

# %%
player.cafecosmos.placeItem(landId, 1, 1, 1)
# Out:
# ---------------------------------------------------------------------------
# ContractCustomError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 player.cafecosmos.placeItem(landId, 1, 1, 1)
#
# File ~/Workspace/mud-aw.py/mud/World.py:130, in World._wrap_function.<locals>.wrapped_function(*args, **kwargs)
#     128             error_msg = f"{error} when calling {func_name}"
#     129             new_error = type(e)((error_msg,))
# --> 130             raise new_error from None
#     131 raise e
#
# ContractCustomError: (('AccessByNoOperator when calling placeItem',), None)
