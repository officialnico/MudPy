# %%
from mud import MUDIndexerSDK

# %%
indexer_url = "https://indexer.mud.garnetchain.com/q"
world_address = "0x0209FE2b6C1a2B8cE12D8d9D6cf2D78a3Ff324FE"
mud_config_path = "./cafecosmos-contracts/mud.config.ts"

sdk = MUDIndexerSDK(indexer_url=indexer_url,
                    world_address=world_address,
                    mud_config_path=mud_config_path)

# %%
sdk.tables.CraftingRecipe.get(xp=1)
# Out:
# [{'output': '5',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['128'],
#   'quantities': ['1']},
#  {'output': '26',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['28', '21', '19'],
#   'quantities': ['4', '4', '1']},
#  {'output': '27',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['20'],
#   'quantities': ['1']},
#  {'output': '28',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['21'],
#   'quantities': ['2']},
#  {'output': '29',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['19', '20'],
#   'quantities': ['4', '1']},
#  {'output': '30',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['8', '12', '13', '106', '6'],
#   'quantities': ['1', '1', '1', '1', '1']},
#  {'output': '31',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['3', '13', '6', '17', '12', '8'],
#   'quantities': ['1', '1', '1', '1', '1', '1']},
#  {'output': '32',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['2', '12', '106'],
#   'quantities': ['1', '1', '1']},
#  {'output': '33',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['129', '4', '11', '14', '6'],
#   'quantities': ['1', '1', '1', '1', '1']},
#  {'output': '34',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['15', '10', '14', '4', '6'],
#   'quantities': ['1', '1', '1', '1', '1']},
#  {'output': '35',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['7'],
#   'quantities': ['9']},
#  {'output': '37',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['129'],
#   'quantities': ['1']},
#  {'output': '43',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['14'],
#   'quantities': ['1']},
#  {'output': '49',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['18'],
#   'quantities': ['1']},
#  {'output': '68',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['19', '29', '28', '107'],
#   'quantities': ['3', '1', '1', '1']},
#  {'output': '72',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['19', '29', '28', '107', '20'],
#   'quantities': ['3', '1', '1', '1', '1']},
#  {'output': '74',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['27', '29', '28', '20'],
#   'quantities': ['2', '1', '1', '1']},
#  {'output': '76',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['107', '19', '28'],
#   'quantities': ['1', '3', '3']},
#  {'output': '78',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['20', '19', '107', '22'],
#   'quantities': ['1', '2', '1', '3']},
#  {'output': '79',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['27', '19', '28', '105', '26'],
#   'quantities': ['1', '3', '1', '1', '1']},
#  {'output': '80',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['19', '20', '27', '28'],
#   'quantities': ['6', '1', '1', '1']},
#  {'output': '81',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['26', '21', '80', '20', '28'],
#   'quantities': ['1', '3', '1', '1', '1']},
#  {'output': '82',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['23', '20', '25'],
#   'quantities': ['1', '1', '3']},
#  {'output': '83',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['27', '29', '28'],
#   'quantities': ['2', '1', '1']},
#  {'output': '89',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['90', '20'],
#   'quantities': ['1', '1']},
#  {'output': '90',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['25'],
#   'quantities': ['4']},
#  {'output': '92',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['25', '24'],
#   'quantities': ['3', '2']},
#  {'output': '93',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['24'],
#   'quantities': ['5']},
#  {'output': '94',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['25'],
#   'quantities': ['5']},
#  {'output': '95',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['37', '22', '107'],
#   'quantities': ['1', '3', '1']},
#  {'output': '96',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['23', '25'],
#   'quantities': ['5', '2']},
#  {'output': '97',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['25'],
#   'quantities': ['3']},
#  {'output': '98',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['24'],
#   'quantities': ['3']},
#  {'output': '99',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['25', '24'],
#   'quantities': ['2', '1']},
#  {'output': '107',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['28', '25'],
#   'quantities': ['1', '3']},
#  {'output': '108',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['20', '23'],
#   'quantities': ['2', '2']},
#  {'output': '110',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['20', '23'],
#   'quantities': ['3', '2']},
#  {'output': '111',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['20', '23'],
#   'quantities': ['3', '2']},
#  {'output': '112',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['20', '23'],
#   'quantities': ['2', '2']},
#  {'output': '116',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['24', '25'],
#   'quantities': ['3', '6']},
#  {'output': '123',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['1', '16', '14', '129'],
#   'quantities': ['1', '1', '1', '1']},
#  {'output': '124',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['24', '19', '20', '25'],
#   'quantities': ['2', '1', '1', '2']},
#  {'output': '125',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['27'],
#   'quantities': ['3']},
#  {'output': '126',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['25', '24'],
#   'quantities': ['4', '2']},
#  {'output': '136',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['28', '20', '19', '26', '80'],
#   'quantities': ['4', '1', '2', '1', '1']},
#  {'output': '911',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['11', '14', '6', '129'],
#   'quantities': ['1', '1', '1', '1']},
#  {'output': '963',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['21', '26'],
#   'quantities': ['4', '1']},
#  {'output': '982',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['2', '105'],
#   'quantities': ['2', '1']},
#  {'output': '984',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['105', '4', '983'],
#   'quantities': ['1', '1', '1']},
#  {'output': '987',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['20', '19'],
#   'quantities': ['5', '3']},
#  {'output': '991',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['1007', '19'],
#   'quantities': ['3', '2']},
#  {'output': '993',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['79', '28', '136'],
#   'quantities': ['1', '3', '1']},
#  {'output': '995',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['23', '20', '24', '82'],
#   'quantities': ['1', '1', '2', '1']},
#  {'output': '996',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['26', '83', '21'],
#   'quantities': ['1', '1', '3']},
#  {'output': '1007',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['23'],
#   'quantities': ['3']},
#  {'output': '1010',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['20'],
#   'quantities': ['3']},
#  {'output': '1011',
#   'outputquantity': '1',
#   'xp': '1',
#   'exists': True,
#   'inputs': ['78', '28', '1022'],
#   'quantities': ['1', '1', '2']}]
